# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('C:\\Users\\arund\\Desktop\\Academic\\Internships\\EDF\\Task 2\\Termreason.csv',skiprows=0)
column_headers=df.columns.values.tolist()
Y=df[column_headers[2]].values.tolist()
X_ticks=df[column_headers[1]].values.tolist()

# %%
df1 = pd.read_csv('C:\\Users\\arund\\Desktop\\Academic\\Internships\\EDF\\Task 2\\Termreason - Term_CoT.csv',skiprows=0)
column_headers1=df1.columns.values.tolist()
Y1=df1[column_headers1[2]].values.tolist()
index1=df1[column_headers1[3]].values.tolist()

# %%
#X_ticks=['Moved out','Lost-COS','COT before COS', 'Deceased','Disconnected','Lost-ET','Demolished']

# %%
df2 = pd.read_csv('C:\\Users\\arund\\Desktop\\Academic\\Internships\\EDF\\Task 2\\Termreason - Term_CoS.csv',skiprows=0)
column_headers2=df2.columns.values.tolist()
Y2=df2[column_headers2[2]].values.tolist()
index2=df2[column_headers2[3]].values.tolist()

# %%
bar_width=0.5
index=range(1,len(X_ticks)+1)

fig,ax=plt.subplots(tight_layout=True, figsize=(14,6))

plt.bar(index1,Y1,bar_width,color='lightcoral',label='A')
plt.bar(index2,Y2,bar_width,color='darkred',label='B')

for i in range(0,3):
    plt.text(index[i], Y[i] + 0.05, "%dk"%(Y[i]/1000),color='maroon', ha='center', va= 'bottom',fontsize=9,fontweight='bold')
for i in range(3,len(Y)):
    plt.text(index[i], Y[i] + 0.05, Y[i],color='maroon', ha='center', va= 'bottom',fontsize=9,fontweight='bold')

ax.set_title('---------------xxxxxxxxxx------------------',fontsize=12,fontweight='bold')
ax.set_xlabel('----XXXX----',fontsize=12,fontweight='bold')
ax.set_ylabel('----XXXX----',fontsize=12,fontweight='bold')
ax.legend()
ax.set_xticks(index)
#ax.set_xticklabels(X_ticks,fontsize=12)
plt.show()
