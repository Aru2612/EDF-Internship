# %%
import numpy as np
import matplotlib.pyplot as plt
import textwrap

import warnings
warnings.filterwarnings("ignore")

# %%
fig, ax = plt.subplots(figsize=(6,6), subplot_kw=dict(aspect="equal"))
colors=['lightcoral','indianred','firebrick','maroon']
labels=['---XXX---','---XXX---','---XXX---','---XXX---']
data=['146473','151654','319886','416154']

wedges,texts,autotexts=ax.pie(data, labels=labels,labeldistance=0.65,pctdistance=0.8,radius=1.2,textprops={'fontsize':'10','weight':'bold','ha':'center','va':'top','color':'w'}, autopct='%1.1f%%', shadow=True, startangle=90,colors=colors)
plt.setp(autotexts, size=10,weight="bold", color='w',ha='center',va='baseline')

for w in wedges:
    w.set_linewidth(0.1)
    w.set_edgecolor('k')

ax.set_title("-------xxxxxxxxx--------",fontsize=16,fontweight='bold')
plt.show()
